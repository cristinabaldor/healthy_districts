# %% [markdown]
# # Health and demographic trends by congressional district

# %% [markdown]
# This ETL project will create a database that allows for comparison of healthcare and demographic metrics by congressional district, and representation in Congress (including party affiliation).

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import os
import csv
import requests
import json
import geopandas
from os.path import join, basename
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func

# %%
#Creating SQL engine
engine = create_engine('sqlite:///healthydistricts.db', echo=False)

# %%
#Reading in a data set of health outcomes by congressional district downloaded from: 
# https://www.tfah.org/congressional-districts/.
districts_df_org=pd.read_csv('district_data.csv')
districts_df_org.head()
# Out:
#    CD116 State  District State-District lackinsurance lackinsurance_LCL  \
# 0    101    AL         1          AL-01         16.3%             16.2%
# 1    102    AL         2          AL-02         16.2%             16.2%
# 2    103    AL         3          AL-03         15.7%             15.7%
# 3    104    AL         4          AL-04           15%               15%
# 4    105    AL         5          AL-05         14.9%             14.9%
#
#   lackinsurance_UCL checkup chekup_LCL checkup_UCL  ...  \
# 0             16.3%   72.3%      72.3%       72.4%  ...
# 1             16.3%     72%        72%       72.1%  ...
# 2             15.8%     71%      70.9%         71%  ...
# 3               15%   70.3%      70.3%       70.4%  ...
# 4             14.9%     70%      69.9%       70.1%  ...
#
#   physical_inactivity_UCL  mcost mcost_LCL mcost_UCL  mhlth mhlth_LCL  \
# 0                   33.2%  16.4%     16.3%     16.4%  15.2%     15.1%
# 1                   32.7%  16.2%     16.2%     16.3%    15%     14.9%
# 2                   32.2%  16.1%     16.1%     16.1%  15.3%     15.2%
# 3                   33.7%    15%       15%       15%    15%     14.9%
# 4                   29.3%    15%     14.9%       15%  14.4%     14.4%
#
#   mhlth_UCL obesity obesity_LCL obesity_UCL
# 0   #VALUE!   34.4%       34.3%       34.4%
# 1       15%   35.6%       35.5%       35.6%
# 2     15.3%   34.4%       34.3%       34.5%
# 3       15%   34.5%       34.4%       34.5%
# 4     14.5%   34.1%         34%       34.1%
#
# [5 rows x 37 columns]

# %%
#The LCL and UCL columns represent the lower- and upper- confidence levels for the metrics. 
#Here those columns are removed.
districts_data_reduced = districts_df_org.drop(columns=['lackinsurance_LCL', 
                                                    'lackinsurance_UCL', 
                                                    'chekup_LCL', 
                                                    'checkup_UCL',
                                                    'cholscreen_LCL', 
                                                    'cholscreen_UCL', 
                                                    'diabetes_LCL',
                                                    'diabetes_UCL',
                                                    'flushot_LCL', 
                                                    'flushot_UCL', 
                                                    'ghlth_LCL', 'ghlth_UCL', 
                                                    'physical_inactivity_LCL', 
                                                    'physical_inactivity_UCL',
                                                     'physical_inactivity_LCL', 
                                                    'physical_inactivity_UCL',
                                                    'mcost_LCL', 
                                                    'mcost_UCL',
                                                    'mhlth_LCL', 
                                                    'mhlth_UCL',
                                                    'obesity_LCL', 
                                                    'obesity_UCL',
                                                    'csmoking_LCL', 
                                                    'csmoking_UCL',
                                                   ])

# %%
# Renaming C116 to GEOID column for matching with other data 
districts_df=districts_data_reduced.rename(columns={'CD116':"GEOID",
                                                   'State-District':'state_district'
                                                   })
districts_df['GEOID']=districts_df['GEOID'].astype(str).str.zfill(4)

# %%
districts_df.head()
# Out:
#   GEOID State  District state_district lackinsurance checkup cholscreen  \
# 0  0101    AL         1          AL-01         16.3%   72.3%      81.1%
# 1  0102    AL         2          AL-02         16.2%     72%      81.1%
# 2  0103    AL         3          AL-03         15.7%     71%      80.1%
# 3  0104    AL         4          AL-04           15%   70.3%      81.2%
# 4  0105    AL         5          AL-05         14.9%     70%      81.1%
#
#   csmoking diabetes flushot  ghlth physical_inactivity  mcost  mhlth obesity
# 0      20%    12.5%   38.8%  22.9%               33.1%  16.4%  15.2%   34.4%
# 1    19.9%    12.7%   38.6%  23.2%               32.6%  16.2%    15%   35.6%
# 2    20.2%    12.5%   39.8%  23.1%               32.1%  16.1%  15.3%   34.4%
# 3    20.2%    12.3%   39.8%  23.5%               33.7%    15%    15%   34.5%
# 4    18.5%    11.2%   39.7%  21.4%               29.2%    15%  14.4%   34.1%

# %%
#Converting percentages from strings to floats
districts_df['lackinsurance']=districts_df['lackinsurance'].str.strip('%').astype('float')/100.0
districts_df['checkup']=districts_df['checkup'].str.strip('%').astype('float')/100.0
districts_df['cholscreen']=districts_df['cholscreen'].str.strip('%').astype('float')/100.0
districts_df['csmoking']=districts_df['csmoking'].str.strip('%').astype('float')/100.0
districts_df['diabetes']=districts_df['diabetes'].str.strip('%').astype('float')/100.0
districts_df['flushot']=districts_df['flushot'].str.strip('%').astype('float')/100.0
districts_df['ghlth']=districts_df['ghlth'].str.strip('%').astype('float')/100.0
districts_df['physical_inactivity']=districts_df['physical_inactivity'].str.strip('%').astype('float')/100.0
districts_df['mcost']=districts_df['mcost'].str.strip('%').astype('float')/100.0
districts_df['mhlth']=districts_df['mhlth'].str.strip('%').astype('float')/100.0
districts_df['obesity']=districts_df['obesity'].str.strip('%').astype('float')/100.0

# %%
districts_df.head()
# Out:
#   GEOID State  District state_district  lackinsurance  checkup  cholscreen  \
# 0  0101    AL         1          AL-01          0.163    0.723       0.811
# 1  0102    AL         2          AL-02          0.162    0.720       0.811
# 2  0103    AL         3          AL-03          0.157    0.710       0.801
# 3  0104    AL         4          AL-04          0.150    0.703       0.812
# 4  0105    AL         5          AL-05          0.149    0.700       0.811
#
#    csmoking  diabetes  flushot  ghlth  physical_inactivity  mcost  mhlth  \
# 0     0.200     0.125    0.388  0.229                0.331  0.164  0.152
# 1     0.199     0.127    0.386  0.232                0.326  0.162  0.150
# 2     0.202     0.125    0.398  0.231                0.321  0.161  0.153
# 3     0.202     0.123    0.398  0.235                0.337  0.150  0.150
# 4     0.185     0.112    0.397  0.214                0.292  0.150  0.144
#
#    obesity
# 0    0.344
# 1    0.356
# 2    0.344
# 3    0.345
# 4    0.341

# %%
acsurl = "https://api.census.gov/data/2018/acs/acs1?get=NAME,B01001_001E,B02001_002E,B02001_003E,B02001_004E,B02001_005E,B02001_006E,B02001_007E,B02001_008E,B03003_003E,B29001_001E,B19013_001E,B19301_001E,B25077_001E,B25064_001E,B19083_001E,B25001_001E,B25002_002E,B25003_002E,B25003_003E,B25002_003E&for=congressional%20district:*"

#Requesting API data in JSON format, setting first row imported as headers for dataframe
acs_response = requests.get(f"{acsurl}").json()
acs_df=pd.DataFrame(acs_response)
acs_df.columns = acs_df.iloc[0]
acs_df= acs_df[1:]

# %%
acs_df.head()
# Out:
# 0                                               NAME B01001_001E B02001_002E  \
# 1  Congressional District 20 (116th Congress), Ca...      739352      428821
# 2  Congressional District 13 (116th Congress), Fl...      735935      580519
# 3  Congressional District 1 (116th Congress), Min...      678418      606439
# 4  Congressional District 10 (116th Congress), Ne...      759704      218853
# 5    Congressional District 5 (116th Congress), Ohio      717088      654248
#
# 0 B02001_003E B02001_004E B02001_005E B02001_006E B02001_007E B02001_008E  \
# 1       14945        7779       40200        2653      213127       31827
# 2       91631        2073       26641         756        9233       25082
# 3       21905        2013       18839        1141       13714       14367
# 4      390745        1661       54128         241       75887       18189
# 5       18872        1250        9691         857       10590       21580
#
# 0 B03003_003E  ... B25077_001E B25064_001E B19083_001E B25001_001E  \
# 1      400149  ...      647600        1560      0.4690      251904
# 2       78500  ...      208900        1109      0.4805      391150
# 3       46054  ...      177600         775      0.4400      294916
# 4      160348  ...      306400        1170      0.5086      306523
# 5       37722  ...      146400         731      0.4362      313442
#
# 0 B25002_002E B25003_002E B25003_003E B25002_003E state congressional district
# 1      225394      120933      104461       26510    06                     20
# 2      303069      195680      107389       88081    12                     13
# 3      272152      199117       73035       22764    27                     01
# 4      275644      106700      168944       30879    34                     10
# 5      289660      211003       78657       23782    39                     05
#
# [5 rows x 23 columns]

# %%
#Converting codes to population types, guide here: http://proximityone.com/cd.htm

acs_df = acs_df.rename(columns={"B01001_001E": "totalpop",
                                      "B02001_002E": "white",
                                      "B02001_003E": "black",
                                      "B02001_004E": "amerindian_native",
                                      "B02001_005E": "asian",
                                      "B02001_006E": "hawaiian_pacific",
                                      "B02001_007E": "other_race",
                                      "B02001_008E": "two_more_races",
                                      "B03003_003E": "hispanic_latino",
                                        "B29001_001E": "citizen_voters",
                                      "B19013_001E": "median_household_income",
                                      "B19301_001E": "per_capita_income",
                                      "B25077_001E": "median_housing_value",
                                      "B25064_001E": "median_gross_rent",
                                      "B19083_001E": "gini_index_of_income_inequality",
                                      "B25001_001E": "total_housing_units",
                                      "B25002_002E": "occupied_units",
                                      "B25003_002E": "owner_occupied_units",
                                      "B25003_003E": "renter_occupied_units",
                                      "B25002_003E": "vacant_units",
                                      "state": "state",
                                      "congressional district": "district"})
#Adding a GEOID Column concatenating State and District Codes to get GEOID, which will be Primary Key in database
acs_df["GEOID"] = acs_df["state"] + acs_df["district"]
acs_df.keys()
# Out:
# Index(['NAME', 'totalpop', 'white', 'black', 'amerindian_native', 'asian',
#        'hawaiian_pacific', 'other_race', 'two_more_races', 'hispanic_latino',
#        'citizen_voters', 'median_household_income', 'per_capita_income',
#        'median_housing_value', 'median_gross_rent',
#        'gini_index_of_income_inequality', 'total_housing_units',
#        'occupied_units', 'owner_occupied_units', 'renter_occupied_units',
#        'vacant_units', 'state', 'district', 'GEOID'],
#       dtype='object', name=0)

# %%
#Converting to percentages for demographic information
acs_df['totalpop']=acs_df['totalpop'].astype('float')
acs_df['median_household_income']=acs_df['median_household_income'].astype('float')
acs_df['white']=acs_df['white'].astype('float')
acs_df['black']=acs_df['black'].astype('float')
acs_df['asian']=acs_df['asian'].astype('float')
acs_df['amerindian_native']=acs_df['amerindian_native'].astype('float')
acs_df['hawaiian_pacific']=acs_df['hawaiian_pacific'].astype('float')
acs_df['other_race']=acs_df['other_race'].astype('float')
acs_df['two_more_races']=acs_df['two_more_races'].astype('float')
acs_df['hispanic_latino']=acs_df['hispanic_latino'].astype('float')
acs_df['citizen_voters']=acs_df['citizen_voters'].astype('float')
acs_df.head()
# Out:
# 0                                               NAME  totalpop     white  \
# 1  Congressional District 20 (116th Congress), Ca...  739352.0  428821.0
# 2  Congressional District 13 (116th Congress), Fl...  735935.0  580519.0
# 3  Congressional District 1 (116th Congress), Min...  678418.0  606439.0
# 4  Congressional District 10 (116th Congress), Ne...  759704.0  218853.0
# 5    Congressional District 5 (116th Congress), Ohio  717088.0  654248.0
#
# 0     black  amerindian_native    asian  hawaiian_pacific  other_race  \
# 1   14945.0             7779.0  40200.0            2653.0    213127.0
# 2   91631.0             2073.0  26641.0             756.0      9233.0
# 3   21905.0             2013.0  18839.0            1141.0     13714.0
# 4  390745.0             1661.0  54128.0             241.0     75887.0
# 5   18872.0             1250.0   9691.0             857.0     10590.0
#
# 0  two_more_races  hispanic_latino  ...  median_gross_rent  \
# 1         31827.0         400149.0  ...               1560
# 2         25082.0          78500.0  ...               1109
# 3         14367.0          46054.0  ...                775
# 4         18189.0         160348.0  ...               1170
# 5         21580.0          37722.0  ...                731
#
# 0  gini_index_of_income_inequality total_housing_units occupied_units  \
# 1                           0.4690              251904         225394
# 2                           0.4805              391150         303069
# 3                           0.4400              294916         272152
# 4                           0.5086              306523         275644
# 5                           0.4362              313442         289660
#
# 0 owner_occupied_units renter_occupied_units vacant_units state district GEOID
# 1               120933                104461        26510    06       20  0620
# 2               195680                107389        88081    12       13  1213
# 3               199117                 73035        22764    27       01  2701
# 4               106700                168944        30879    34       10  3410
# 5               211003                 78657        23782    39       05  3905
#
# [5 rows x 24 columns]

# %%
acs_df['white'] = acs_df['white']/acs_df['totalpop']
acs_df['black'] = acs_df['black']/acs_df['totalpop']
acs_df['amerindian_native'] = acs_df['amerindian_native']/acs_df['totalpop']
acs_df['asian'] = acs_df['asian']/acs_df['totalpop']
acs_df['hawaiian_pacific'] = acs_df['hawaiian_pacific']/acs_df['totalpop']
acs_df['other_race'] = acs_df['other_race']/acs_df['totalpop']
acs_df['two_more_races'] = acs_df['two_more_races']/acs_df['totalpop']
acs_df['hispanic_latino'] = acs_df['hispanic_latino']/acs_df['totalpop']
acs_df['citizen_voters'] = acs_df['citizen_voters']/acs_df['totalpop']
acs_df.head()
# Out:
# 0                                               NAME  totalpop     white  \
# 1  Congressional District 20 (116th Congress), Ca...  739352.0  0.579996
# 2  Congressional District 13 (116th Congress), Fl...  735935.0  0.788818
# 3  Congressional District 1 (116th Congress), Min...  678418.0  0.893902
# 4  Congressional District 10 (116th Congress), Ne...  759704.0  0.288077
# 5    Congressional District 5 (116th Congress), Ohio  717088.0  0.912368
#
# 0     black  amerindian_native     asian  hawaiian_pacific  other_race  \
# 1  0.020214           0.010521  0.054372          0.003588    0.288262
# 2  0.124510           0.002817  0.036200          0.001027    0.012546
# 3  0.032288           0.002967  0.027769          0.001682    0.020215
# 4  0.514338           0.002186  0.071249          0.000317    0.099890
# 5  0.026318           0.001743  0.013514          0.001195    0.014768
#
# 0  two_more_races  hispanic_latino  ...  median_gross_rent  \
# 1        0.043047         0.541216  ...               1560
# 2        0.034082         0.106667  ...               1109
# 3        0.021177         0.067884  ...                775
# 4        0.023942         0.211066  ...               1170
# 5        0.030094         0.052604  ...                731
#
# 0  gini_index_of_income_inequality total_housing_units occupied_units  \
# 1                           0.4690              251904         225394
# 2                           0.4805              391150         303069
# 3                           0.4400              294916         272152
# 4                           0.5086              306523         275644
# 5                           0.4362              313442         289660
#
# 0 owner_occupied_units renter_occupied_units vacant_units state district GEOID
# 1               120933                104461        26510    06       20  0620
# 2               195680                107389        88081    12       13  1213
# 3               199117                 73035        22764    27       01  2701
# 4               106700                168944        30879    34       10  3410
# 5               211003                 78657        23782    39       05  3905
#
# [5 rows x 24 columns]

# %%
#Requesting current updated congressional data 
#from https://github.com/unitedstates/congress-legislators

congressurl = "https://theunitedstates.io/congress-legislators/legislators-current.csv"
congress_response = requests.get(f"{congressurl}",stream=True).content.decode('utf-8')
cr = csv.reader(congress_response.splitlines(), delimiter=',')
my_list = list(cr)
congress = pd.DataFrame(my_list[1:],columns=my_list[0])
congress['district']=congress['district'].astype(str).str.zfill(2)
#stripping extra spaces from State abbreviations
congress.state=congress.state.str.strip()
congress.head()
# Out:
#   last_name first_name middle_name suffix nickname             full_name  \
# 0     Brown    Sherrod                                     Sherrod Brown
# 1  Cantwell      Maria                                    Maria Cantwell
# 2    Cardin   Benjamin          L.                    Benjamin L. Cardin
# 3    Carper     Thomas     Richard                      Thomas R. Carper
# 4     Casey     Robert          P.    Jr.      Bob  Robert P. Casey, Jr.
#
#      birthday gender type state  ... opensecrets_id lis_id  \
# 0  1952-11-09      M  sen    OH  ...      N00003535   S307
# 1  1958-10-13      F  sen    WA  ...      N00007836   S275
# 2  1943-10-05      M  sen    MD  ...      N00001955   S308
# 3  1947-01-23      M  sen    DE  ...      N00012508   S277
# 4  1960-04-13      M  sen    PA  ...      N00027503   S309
#
#                fec_ids cspan_id govtrack_id votesmart_id  ballotpedia_id  \
# 0  H2OH13033,S6OH00163     5051      400050        27018   Sherrod Brown
# 1  S8WA00194,H2WA01054    26137      300018        27122  Maria Cantwell
# 2  H6MD03177,S6MD03177     4004      400064        26888      Ben Cardin
# 3            S8DE00079      663      300019        22421      Tom Carper
# 4            S6PA00217    47036      412246         2541  Bob Casey, Jr.
#
#   washington_post_id icpsr_id    wikipedia_id
# 0                       29389   Sherrod Brown
# 1                       39310  Maria Cantwell
# 2                       15408      Ben Cardin
# 3                       15015      Tom Carper
# 4                       40703   Bob Casey Jr.
#
# [5 rows x 34 columns]

# %%
# Get indexes where type column is sen (Senators)
indexNames = congress[congress['type'] == 'sen'].index
 
# Delete these row indexes from dataFrame
congress.drop(indexNames , inplace=True)
congress.head()
# Out:
#      last_name first_name middle_name suffix nickname               full_name  \
# 28    Aderholt     Robert          B.                      Robert B. Aderholt
# 30        Bass      Karen                                          Karen Bass
# 32   Bilirakis        Gus          M.                        Gus M. Bilirakis
# 33      Bishop    Sanford          D.    Jr.           Sanford D. Bishop, Jr.
# 35  Blumenauer       Earl                                     Earl Blumenauer
#
#       birthday gender type state  ... opensecrets_id lis_id    fec_ids  \
# 28  1965-07-22      M  rep    AL  ...      N00003028         H6AL04098
# 30  1953-10-03      F  rep    CA  ...      N00031877         H0CA33117
# 32  1963-02-08      M  rep    FL  ...      N00027462         H6FL09070
# 33  1947-02-04      M  rep    GA  ...      N00002674         H2GA02031
# 35  1948-08-16      M  rep    OR  ...      N00007727         H6OR03064
#
#    cspan_id govtrack_id votesmart_id      ballotpedia_id washington_post_id  \
# 28    45516      400004          441  Robert B. Aderholt
# 30    62502      412404        28963          Karen Bass
# 32  1022873      412250        17318    Gus M. Bilirakis
# 33    26194      400030        26817  Sanford Bishop Jr.
# 35    43809      400033          367     Earl Blumenauer
#
#    icpsr_id     wikipedia_id
# 28    29701  Robert Aderholt
# 30    21110       Karen Bass
# 32    20758    Gus Bilirakis
# 33    29339   Sanford Bishop
# 35    29588  Earl Blumenauer
#
# [5 rows x 34 columns]

# %%
#Getting State FIPS Codes with State Numbers to go with State Abbreviations in Congress file
fips=pd.read_csv('us-state-ansi-fips.csv')
fips=fips.rename(columns={"stname": "name",
                        " st": "number",
                        " stusps": "state"})
fips['number']=fips['number'].astype(str).str.zfill(2)
#Stripping extra spaces from state abbreviations that were preventing a merge
fips.state = fips.state.str.strip()
fips.head()
# Out:
#          name number state
# 0     Alabama     01    AL
# 1      Alaska     02    AK
# 2     Arizona     04    AZ
# 3    Arkansas     05    AR
# 4  California     06    CA

# %%
#Merging on 'state' to get state numbers into congress dataframe results in NaN
congress = congress.merge(fips, on = 'state', how='inner')
#Adding GEOID column
congress["GEOID"] = congress["number"] + congress["district"]

# %%
congress.head()
# Out:
#   last_name first_name middle_name suffix nickname           full_name  \
# 0  Aderholt     Robert          B.                  Robert B. Aderholt
# 1    Brooks         Mo                                       Mo Brooks
# 2    Rogers       Mike                                     Mike Rogers
# 3    Sewell      Terri          A.                        Terri Sewell
# 4    Palmer       Gary          J.                      Gary J. Palmer
#
#      birthday gender type state  ... cspan_id govtrack_id votesmart_id  \
# 0  1965-07-22      M  rep    AL  ...    45516      400004          441
# 1  1954-04-29      M  rep    AL  ...    94888      412395       121610
# 2  1958-07-16      M  rep    AL  ...  1014740      400341         5705
# 3  1965-01-01      F  rep    AL  ...   623257      412396       121621
# 4  1954-05-14      M  rep    AL  ...    76094      412608       146274
#
#           ballotpedia_id washington_post_id icpsr_id  \
# 0     Robert B. Aderholt                       29701
# 1              Mo Brooks                       21193
# 2  Mike Rogers (Alabama)                       20301
# 3           Terri Sewell                       21102
# 4            Gary Palmer                       21500
#
#                        wikipedia_id     name number GEOID
# 0                   Robert Aderholt  Alabama     01  0104
# 1                         Mo Brooks  Alabama     01  0105
# 2  Mike Rogers (Alabama politician)  Alabama     01  0103
# 3                      Terri Sewell  Alabama     01  0107
# 4          Gary Palmer (politician)  Alabama     01  0106
#
# [5 rows x 37 columns]

# %%
health_acs_merge= pd.merge(acs_df,districts_df, on='GEOID')
health_acs_merge.keys()
# Out:
# Index(['NAME', 'totalpop', 'white', 'black', 'amerindian_native', 'asian',
#        'hawaiian_pacific', 'other_race', 'two_more_races', 'hispanic_latino',
#        'citizen_voters', 'median_household_income', 'per_capita_income',
#        'median_housing_value', 'median_gross_rent',
#        'gini_index_of_income_inequality', 'total_housing_units',
#        'occupied_units', 'owner_occupied_units', 'renter_occupied_units',
#        'vacant_units', 'state', 'district', 'GEOID', 'State', 'District',
#        'state_district', 'lackinsurance', 'checkup', 'cholscreen', 'csmoking',
#        'diabetes', 'flushot', 'ghlth', 'physical_inactivity', 'mcost', 'mhlth',
#        'obesity'],
#       dtype='object')

# %%
health_acs_congress_merge=pd.merge(health_acs_merge, congress, on="GEOID")

# %%
health_acs_congress_merge.keys()
# Out:
# Index(['NAME', 'totalpop', 'white', 'black', 'amerindian_native', 'asian',
#        'hawaiian_pacific', 'other_race', 'two_more_races', 'hispanic_latino',
#        'citizen_voters', 'median_household_income', 'per_capita_income',
#        'median_housing_value', 'median_gross_rent',
#        'gini_index_of_income_inequality', 'total_housing_units',
#        'occupied_units', 'owner_occupied_units', 'renter_occupied_units',
#        'vacant_units', 'state_x', 'district_x', 'GEOID', 'State', 'District',
#        'state_district', 'lackinsurance', 'checkup', 'cholscreen', 'csmoking',
#        'diabetes', 'flushot', 'ghlth', 'physical_inactivity', 'mcost', 'mhlth',
#        'obesity', 'last_name', 'first_name', 'middle_name', 'suffix',
#        'nickname', 'full_name', 'birthday', 'gender', 'type', 'state_y',
#        'district_y', 'senate_class', 'party', 'url', 'address', 'phone',
#        'contact_form', 'rss_url', 'twitter', 'facebook', 'youtube',
#        'youtube_id', 'bioguide_id', 'thomas_id', 'opensecrets_id', 'lis_id',
#        'fec_ids', 'cspan_id', 'govtrack_id', 'votesmart_id', 'ballotpedia_id',
#        'washington_post_id', 'icpsr_id', 'wikipedia_id', 'name', 'number'],
#       dtype='object')

# %%
healthy_districts_df = health_acs_congress_merge[['GEOID',
                         'totalpop',
                         'party',
                         'full_name',
                         'gini_index_of_income_inequality' ,
                         'median_household_income',
                         'white',
                         'black',
                         'amerindian_native',
                         'asian',
                         'hawaiian_pacific', 
                         'other_race', 
                         'two_more_races', 
                         'hispanic_latino',
                         'citizen_voters',
                         'state_district', 
                         'lackinsurance',
                         'csmoking',
                         'diabetes',
                         'obesity',
                         'ghlth',
                         'mhlth',
                         'url',
                         'twitter' 
                        ]]

# %%
healthy_districts_df.head()
# Out:
#   GEOID  totalpop       party             full_name  \
# 0  0620  739352.0    Democrat         Jimmy Panetta
# 1  1213  735935.0    Democrat         Charlie Crist
# 2  2701  678418.0  Republican          Jim Hagedorn
# 3  3410  759704.0    Democrat  Donald M. Payne, Jr.
# 4  3905  717088.0  Republican       Robert E. Latta
#
#   gini_index_of_income_inequality  median_household_income     white  \
# 0                          0.4690                  75460.0  0.579996
# 1                          0.4805                  52081.0  0.788818
# 2                          0.4400                  61247.0  0.893902
# 3                          0.5086                  59101.0  0.288077
# 4                          0.4362                  60500.0  0.912368
#
#       black  amerindian_native     asian  ...  citizen_voters  state_district  \
# 0  0.020214           0.010521  0.054372  ...        0.588203           CA-20
# 1  0.124510           0.002817  0.036200  ...        0.794756           FL-13
# 2  0.032288           0.002967  0.027769  ...        0.737495           MN-01
# 3  0.514338           0.002186  0.071249  ...        0.652953           NJ-10
# 4  0.026318           0.001743  0.013514  ...        0.765835           OH-05
#
#    lackinsurance  csmoking  diabetes obesity  ghlth  mhlth  \
# 0          0.158     0.123     0.091   0.240  0.191  0.126
# 1          0.187     0.175     0.108   0.277  0.191  0.132
# 2          0.098     0.146     0.081   0.310  0.128  0.100
# 3          0.157     0.165     0.124   0.328  0.215  0.137
# 4          0.085     0.182     0.105   0.345  0.162  0.128
#
#                           url          twitter
# 0   https://panetta.house.gov  RepJimmyPanetta
# 1     https://crist.house.gov  repcharliecrist
# 2  https://hagedorn.house.gov      RepHagedorn
# 3     https://payne.house.gov   RepDonaldPayne
# 4     https://latta.house.gov         BobLatta
#
# [5 rows x 24 columns]

# %%
healthy_districts_df.set_index('GEOID')
# Out:
#        totalpop       party             full_name  \
# GEOID
# 0620   739352.0    Democrat         Jimmy Panetta
# 1213   735935.0    Democrat         Charlie Crist
# 2701   678418.0  Republican          Jim Hagedorn
# 3410   759704.0    Democrat  Donald M. Payne, Jr.
# 3905   717088.0  Republican       Robert E. Latta
# ...         ...         ...                   ...
# 3618   722226.0    Democrat  Sean Patrick Maloney
# 3911   678001.0    Democrat       Marcia L. Fudge
# 4204   727449.0    Democrat        Madeleine Dean
# 4825   786976.0  Republican        Roger Williams
# 5109   704831.0  Republican    H. Morgan Griffith
#
#       gini_index_of_income_inequality  median_household_income     white  \
# GEOID
# 0620                           0.4690                  75460.0  0.579996
# 1213                           0.4805                  52081.0  0.788818
# 2701                           0.4400                  61247.0  0.893902
# 3410                           0.5086                  59101.0  0.288077
# 3905                           0.4362                  60500.0  0.912368
# ...                               ...                      ...       ...
# 3618                           0.4665                  82731.0  0.761893
# 3911                           0.5623                  38747.0  0.397482
# 4204                           0.4613                  87168.0  0.795039
# 4825                           0.5012                  71031.0  0.809937
# 5109                           0.4723                  41520.0  0.909069
#
#           black  amerindian_native     asian  hawaiian_pacific  ...  \
# GEOID                                                           ...
# 0620   0.020214           0.010521  0.054372          0.003588  ...
# 1213   0.124510           0.002817  0.036200          0.001027  ...
# 2701   0.032288           0.002967  0.027769          0.001682  ...
# 3410   0.514338           0.002186  0.071249          0.000317  ...
# 3905   0.026318           0.001743  0.013514          0.001195  ...
# ...         ...                ...       ...               ...  ...
# 3618   0.099362           0.002368  0.029524          0.000590  ...
# 3911   0.524545           0.002642  0.025795          0.000482  ...
# 4204   0.096447           0.000419  0.065983          0.000411  ...
# 4825   0.088046           0.004196  0.036372          0.000389  ...
# 5109   0.052325           0.002304  0.016527          0.000919  ...
#
#        citizen_voters  state_district  lackinsurance  csmoking diabetes  \
# GEOID
# 0620         0.588203           CA-20          0.158     0.123    0.091
# 1213         0.794756           FL-13          0.187     0.175    0.108
# 2701         0.737495           MN-01          0.098     0.146    0.081
# 3410         0.652953           NJ-10          0.157     0.165    0.124
# 3905         0.765835           OH-05          0.085     0.182    0.105
# ...               ...             ...            ...       ...      ...
# 3618         0.726051           NY-18          0.099     0.150    0.085
# 3911         0.774045           OH-11          0.136     0.242    0.155
# 4204         0.747438           PA-04          0.066     0.139    0.085
# 4825         0.724594           TX-25          0.173     0.142    0.091
# 5109         0.804895           VA-09          0.118     0.188    0.107
#
#        obesity  ghlth  mhlth                               url  \
# GEOID
# 0620     0.240  0.191  0.126         https://panetta.house.gov
# 1213     0.277  0.191  0.132           https://crist.house.gov
# 2701     0.310  0.128  0.100        https://hagedorn.house.gov
# 3410     0.328  0.215  0.137           https://payne.house.gov
# 3905     0.345  0.162  0.128           https://latta.house.gov
# ...        ...    ...    ...                               ...
# 3618     0.267  0.145  0.116     https://seanmaloney.house.gov
# 3911     0.379  0.256  0.160           https://fudge.house.gov
# 4204     0.253  0.128  0.113            https://dean.house.gov
# 4825     0.302  0.155  0.120        https://williams.house.gov
# 5109     0.312  0.183  0.131  https://morgangriffith.house.gov
#
#                twitter
# GEOID
# 0620   RepJimmyPanetta
# 1213   repcharliecrist
# 2701       RepHagedorn
# 3410    RepDonaldPayne
# 3905          BobLatta
# ...                ...
# 3618    RepSeanMaloney
# 3911    RepMarciaFudge
# 4204           RepDean
# 4825      RepRWilliams
# 5109      RepMGriffith
#
# [432 rows x 23 columns]

# %%
healthy_districts_df=healthy_districts_df.sort_values(by=['state_district'])

# %%
healthy_districts_df
# Out:
#     GEOID  totalpop       party           full_name  \
# 175  0200  737438.0  Republican           Don Young
# 19   0101  715346.0  Republican       Jerry L. Carl
# 325  0102  678122.0  Republican         Barry Moore
# 229  0103  708409.0  Republican         Mike Rogers
# 48   0104  686297.0  Republican  Robert B. Aderholt
# ..    ...       ...         ...                 ...
# 43   5508  735997.0  Republican      Mike Gallagher
# 198  5401  606136.0  Republican   David B. McKinley
# 167  5402  624120.0  Republican    Alexander Mooney
# 309  5403  575576.0  Republican     Carol D. Miller
# 153  5600  577737.0  Republican          Liz Cheney
#
#     gini_index_of_income_inequality  median_household_income     white  \
# 175                          0.4322                  74346.0  0.643519
# 19                           0.4824                  46445.0  0.670933
# 325                          0.4763                  48290.0  0.629199
# 229                          0.4923                  45832.0  0.693084
# 48                           0.4792                  45387.0  0.861266
# ..                              ...                      ...       ...
# 43                           0.4314                  61423.0  0.899565
# 198                          0.4695                  46867.0  0.939530
# 167                          0.4650                  48525.0  0.916080
# 309                          0.4803                  36863.0  0.935664
# 153                          0.4555                  61584.0  0.914695
#
#         black  amerindian_native     asian  ...  citizen_voters  \
# 175  0.034168           0.151024  0.062895  ...        0.721747
# 19   0.275239           0.009774  0.014856  ...        0.761120
# 325  0.321442           0.004185  0.010974  ...        0.761360
# 229  0.259665           0.001835  0.018420  ...        0.767712
# 48   0.074561           0.006398  0.004476  ...        0.751425
# ..        ...                ...       ...  ...             ...
# 43   0.016375           0.025837  0.021440  ...        0.755716
# 198  0.026959           0.001374  0.009511  ...        0.802340
# 167  0.046199           0.002166  0.008615  ...        0.780632
# 309  0.040836           0.000771  0.004026  ...        0.795070
# 153  0.006347           0.028014  0.010051  ...        0.750591
#
#      state_district  lackinsurance  csmoking  diabetes obesity  ghlth  mhlth  \
# 175           AK-00          0.117     0.176     0.074   0.326  0.145  0.113
# 19            AL-01          0.163     0.200     0.125   0.344  0.229  0.152
# 325           AL-02          0.162     0.199     0.127   0.356  0.232  0.150
# 229           AL-03          0.157     0.202     0.125   0.344  0.231  0.153
# 48            AL-04          0.150     0.202     0.123   0.345  0.235  0.150
# ..              ...            ...       ...       ...     ...    ...    ...
# 43            WI-08          0.082     0.156     0.079   0.321  0.133  0.109
# 198           WV-01          0.101     0.228     0.125   0.363  0.224  0.158
# 167           WV-02          0.096     0.222     0.131   0.377  0.231  0.154
# 309           WV-03          0.106     0.253     0.141   0.385  0.272  0.171
# 153           WY-00          0.147     0.172     0.082   0.289  0.142  0.113
#
#                               url          twitter
# 175    https://donyoung.house.gov      RepDonYoung
# 19         https://carl.house.gov     RepJerryCarl
# 325  https://barrymoore.house.gov    RepBarryMoore
# 229  https://mikerogers.house.gov  RepMikeRogersAL
# 48     https://aderholt.house.gov  Robert_Aderholt
# ..                            ...              ...
# 43    https://gallagher.house.gov     RepGallagher
# 198    https://mckinley.house.gov      RepMcKinley
# 167      https://mooney.house.gov    RepAlexMooney
# 309      https://miller.house.gov   RepCarolMiller
# 153      https://cheney.house.gov     RepLizCheney
#
# [432 rows x 24 columns]

# %%
c116districts = geopandas.read_file('shapedata/tl_2019_us_cd116.shp')
c116districts['GEOID']=c116districts['GEOID'].astype('str')
c116districts.set_index('GEOID')
# Out:
#       STATEFP CD116FP                   NAMELSAD LSAD CDSESSN  MTFCC FUNCSTAT  \
# GEOID
# 2707       27      07   Congressional District 7   C2     116  G5200        N
# 2702       27      02   Congressional District 2   C2     116  G5200        N
# 2706       27      06   Congressional District 6   C2     116  G5200        N
# 2708       27      08   Congressional District 8   C2     116  G5200        N
# 1701       17      01   Congressional District 1   C2     116  G5200        N
# ...       ...     ...                        ...  ...     ...    ...      ...
# 3613       36      13  Congressional District 13   C2     116  G5200        N
# 3626       36      26  Congressional District 26   C2     116  G5200        N
# 3622       36      22  Congressional District 22   C2     116  G5200        N
# 3609       36      09   Congressional District 9   C2     116  G5200        N
# 3619       36      19  Congressional District 19   C2     116  G5200        N
#
#              ALAND       AWATER     INTPTLAT      INTPTLON  \
# GEOID
# 2707   86581301397   5058057072  +46.5530202  -095.6759048
# 2702    6314304732    241279430  +44.4789680  -092.8530418
# 2706    7460443329    408726474  +45.3368069  -093.8520551
# 2708   72282135057  12448157466  +47.2503370  -092.9638699
# 1701     669183735      2067924  +41.5466708  -087.8357472
# ...            ...          ...          ...           ...
# 3613      26316820      7203018  +40.8388622  -073.9329821
# 3626     567624808     35592440  +42.9618255  -078.8409831
# 3622   13150455532    386871444  +42.8706939  -075.6626641
# 3609      40269799       499820  +40.6421839  -073.9472006
# 3619   20556873459    430600661  +42.2278105  -074.4256329
#
#                                                 geometry
# GEOID
# 2707   POLYGON ((-97.23909 48.96826, -97.23909 48.968...
# 2702   POLYGON ((-93.91131 44.54651, -93.91024 44.548...
# 2706   POLYGON ((-94.64041 45.37072, -94.64039 45.371...
# 2708   POLYGON ((-95.18322 47.41277, -95.16598 47.412...
# 1701   POLYGON ((-88.13677 41.42285, -88.13633 41.422...
# ...                                                  ...
# 3613   POLYGON ((-73.97062 40.81700, -73.97011 40.817...
# 3626   POLYGON ((-79.07537 43.08135, -79.07400 43.083...
# 3622   POLYGON ((-76.47265 42.00007, -76.47213 42.000...
# 3609   POLYGON ((-73.98784 40.65982, -73.98750 40.660...
# 3619   POLYGON ((-75.55548 42.12170, -75.55268 42.121...
#
# [444 rows x 12 columns]

# %%
healthy_districts_map = pd.merge(healthy_districts_df,c116districts, on='GEOID')

# %%
healthy_districts_map=healthy_districts_map.set_index('state_district')

# %%
healthy_districts_map=healthy_districts_map.sort_values(by=['state_district'])

# %%
healthy_districts_map.head()
# Out:
#                GEOID  totalpop       party           full_name  \
# state_district
# AK-00           0200  737438.0  Republican           Don Young
# AL-01           0101  715346.0  Republican       Jerry L. Carl
# AL-02           0102  678122.0  Republican         Barry Moore
# AL-03           0103  708409.0  Republican         Mike Rogers
# AL-04           0104  686297.0  Republican  Robert B. Aderholt
#
#                gini_index_of_income_inequality  median_household_income  \
# state_district
# AK-00                                   0.4322                  74346.0
# AL-01                                   0.4824                  46445.0
# AL-02                                   0.4763                  48290.0
# AL-03                                   0.4923                  45832.0
# AL-04                                   0.4792                  45387.0
#
#                    white     black  amerindian_native     asian  ...  \
# state_district                                                   ...
# AK-00           0.643519  0.034168           0.151024  0.062895  ...
# AL-01           0.670933  0.275239           0.009774  0.014856  ...
# AL-02           0.629199  0.321442           0.004185  0.010974  ...
# AL-03           0.693084  0.259665           0.001835  0.018420  ...
# AL-04           0.861266  0.074561           0.006398  0.004476  ...
#
#                                          NAMELSAD  LSAD  CDSESSN  MTFCC  \
# state_district
# AK-00           Congressional District (at Large)    C1      116  G5200
# AL-01                    Congressional District 1    C2      116  G5200
# AL-02                    Congressional District 2    C2      116  G5200
# AL-03                    Congressional District 3    C2      116  G5200
# AL-04                    Congressional District 4    C2      116  G5200
#
#                 FUNCSTAT          ALAND        AWATER     INTPTLAT  \
# state_district
# AK-00                  N  1478927050067  245394222619  +63.3473560
# AL-01                  N    15713378154    2275494808  +31.0018906
# AL-02                  N    26270004118     303481339  +31.7020846
# AL-03                  N    19537635148     471179602  +33.1505639
# AL-04                  N    23021992971     573809025  +34.1181796
#
#                     INTPTLON  \
# state_district
# AK-00           -152.8397334
# AL-01           -087.7881212
# AL-02           -086.0768417
# AL-03           -085.7002277
# AL-04           -087.2138079
#
#                                                          geometry
# state_district
# AK-00           MULTIPOLYGON (((179.38874 51.94192, 179.40456 ...
# AL-01           POLYGON ((-88.46443 31.69795, -88.46418 31.697...
# AL-02           POLYGON ((-87.42752 31.26274, -87.42750 31.263...
# AL-03           POLYGON ((-86.57780 33.76652, -86.57780 33.768...
# AL-04           POLYGON ((-88.27459 33.53425, -88.27450 33.534...
#
# [5 rows x 35 columns]

# %%
# #Exporting dataframe to SQLite
# healthy_districts_map.to_sql('healthy_districts_map', con=engine,if_exists='replace')

# %%
healthy_districts_df.head()
# Out:
#     GEOID  totalpop       party           full_name  \
# 175  0200  737438.0  Republican           Don Young
# 19   0101  715346.0  Republican       Jerry L. Carl
# 325  0102  678122.0  Republican         Barry Moore
# 229  0103  708409.0  Republican         Mike Rogers
# 48   0104  686297.0  Republican  Robert B. Aderholt
#
#     gini_index_of_income_inequality  median_household_income     white  \
# 175                          0.4322                  74346.0  0.643519
# 19                           0.4824                  46445.0  0.670933
# 325                          0.4763                  48290.0  0.629199
# 229                          0.4923                  45832.0  0.693084
# 48                           0.4792                  45387.0  0.861266
#
#         black  amerindian_native     asian  ...  citizen_voters  \
# 175  0.034168           0.151024  0.062895  ...        0.721747
# 19   0.275239           0.009774  0.014856  ...        0.761120
# 325  0.321442           0.004185  0.010974  ...        0.761360
# 229  0.259665           0.001835  0.018420  ...        0.767712
# 48   0.074561           0.006398  0.004476  ...        0.751425
#
#      state_district  lackinsurance  csmoking  diabetes obesity  ghlth  mhlth  \
# 175           AK-00          0.117     0.176     0.074   0.326  0.145  0.113
# 19            AL-01          0.163     0.200     0.125   0.344  0.229  0.152
# 325           AL-02          0.162     0.199     0.127   0.356  0.232  0.150
# 229           AL-03          0.157     0.202     0.125   0.344  0.231  0.153
# 48            AL-04          0.150     0.202     0.123   0.345  0.235  0.150
#
#                               url          twitter
# 175    https://donyoung.house.gov      RepDonYoung
# 19         https://carl.house.gov     RepJerryCarl
# 325  https://barrymoore.house.gov    RepBarryMoore
# 229  https://mikerogers.house.gov  RepMikeRogersAL
# 48     https://aderholt.house.gov  Robert_Aderholt
#
# [5 rows x 24 columns]

# %%
#Exporting dataframe to SQLite
healthy_districts_df.to_sql('healthy_districts', con=engine,if_exists='replace')

# %%
table_data_df=healthy_districts_df[['state_district',
                             'full_name',
                             'party',
                             'median_household_income',
                             'amerindian_native',
                             'asian',
                             'black',
                             'white',
                             'hispanic_latino',
                             'lackinsurance',
                             'csmoking',
                             'diabetes',
                             'obesity']]

table_data_df.head()
# Out:
#     state_district           full_name       party  median_household_income  \
# 175          AK-00           Don Young  Republican                  74346.0
# 19           AL-01       Jerry L. Carl  Republican                  46445.0
# 325          AL-02         Barry Moore  Republican                  48290.0
# 229          AL-03         Mike Rogers  Republican                  45832.0
# 48           AL-04  Robert B. Aderholt  Republican                  45387.0
#
#      amerindian_native     asian     black     white  hispanic_latino  \
# 175           0.151024  0.062895  0.034168  0.643519         0.071964
# 19            0.009774  0.014856  0.275239  0.670933         0.033747
# 325           0.004185  0.010974  0.321442  0.629199         0.036797
# 229           0.001835  0.018420  0.259665  0.693084         0.031199
# 48            0.006398  0.004476  0.074561  0.861266         0.065177
#
#      lackinsurance  csmoking  diabetes  obesity
# 175          0.117     0.176     0.074    0.326
# 19           0.163     0.200     0.125    0.344
# 325          0.162     0.199     0.127    0.356
# 229          0.157     0.202     0.125    0.344
# 48           0.150     0.202     0.123    0.345

# %%
table_data_df= table_data_df.rename(columns = {'state_district': 'District',
                                     'full_name': 'Representative',
                                     'party': 'Political Party',
                                     'median_household_income': 'Median Income',
                                     'amerindian_native': 'American Indian/Alaskan Native',
                                     'asian': 'Asian',
                                    'black': 'Black',
                                     'white': 'White',
                                     'hispanic_latino': "Hispanic/Latino All Races",
                                     'lackinsurance': 'Uninsured',
                                     'csmoking': 'Currently Smoking',
                                     'diabetes': 'Adult Diabetics',
                                     'obesity': 'Obesity'},
                                   
                                   
                                   
                                   
                                   
                                   )

# %%
table_data_df
# Out:
#     District      Representative Political Party  Median Income  \
# 175    AK-00           Don Young      Republican        74346.0
# 19     AL-01       Jerry L. Carl      Republican        46445.0
# 325    AL-02         Barry Moore      Republican        48290.0
# 229    AL-03         Mike Rogers      Republican        45832.0
# 48     AL-04  Robert B. Aderholt      Republican        45387.0
# ..       ...                 ...             ...            ...
# 43     WI-08      Mike Gallagher      Republican        61423.0
# 198    WV-01   David B. McKinley      Republican        46867.0
# 167    WV-02    Alexander Mooney      Republican        48525.0
# 309    WV-03     Carol D. Miller      Republican        36863.0
# 153    WY-00          Liz Cheney      Republican        61584.0
#
#      American Indian/Alaskan Native     Asian     Black     White  \
# 175                        0.151024  0.062895  0.034168  0.643519
# 19                         0.009774  0.014856  0.275239  0.670933
# 325                        0.004185  0.010974  0.321442  0.629199
# 229                        0.001835  0.018420  0.259665  0.693084
# 48                         0.006398  0.004476  0.074561  0.861266
# ..                              ...       ...       ...       ...
# 43                         0.025837  0.021440  0.016375  0.899565
# 198                        0.001374  0.009511  0.026959  0.939530
# 167                        0.002166  0.008615  0.046199  0.916080
# 309                        0.000771  0.004026  0.040836  0.935664
# 153                        0.028014  0.010051  0.006347  0.914695
#
#      Hispanic/Latino All Races  Uninsured  Currently Smoking  Adult Diabetics  \
# 175                   0.071964      0.117              0.176            0.074
# 19                    0.033747      0.163              0.200            0.125
# 325                   0.036797      0.162              0.199            0.127
# 229                   0.031199      0.157              0.202            0.125
# 48                    0.065177      0.150              0.202            0.123
# ..                         ...        ...                ...              ...
# 43                    0.054284      0.082              0.156            0.079
# 198                   0.012642      0.101              0.228            0.125
# 167                   0.021675      0.096              0.222            0.131
# 309                   0.007606      0.106              0.253            0.141
# 153                   0.100210      0.147              0.172            0.082
#
#      Obesity
# 175    0.326
# 19     0.344
# 325    0.356
# 229    0.344
# 48     0.345
# ..       ...
# 43     0.321
# 198    0.363
# 167    0.377
# 309    0.385
# 153    0.289
#
# [432 rows x 13 columns]

# %%
table_data_df.style.format({'Median Income':"${:,.0f}",
                             'American Indian/Alaskan Native':"{:.2%}",
                             'Asian':"{:.2%}",
                             'Black':"{:.2%}",
                             'White':"{:.2%}",
                             'Hispanic/Latino All Races':"{:.2%}",
                             'Uninsured':"{:.2%}",
                             'Currently Smoking':"{:.2%}",
                             'Adult Diabetics':"{:.2%}",
                             'Obesity':"{:.2%}"
                           
                           
                           
                           })
# Out:
# <style  type="text/css" >
# </style><table id="T_e4567074_62ba_11eb_8466_3e22fb8af6ee" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >District</th>        <th class="col_heading level0 col1" >Representative</th>        <th class="col_heading level0 col2" >Political Party</th>        <th class="col_heading level0 col3" >Median Income</th>        <th class="col_heading level0 col4" >American Indian/Alaskan Native</th>        <th class="col_heading level0 col5" >Asian</th>        <th class="col_heading level0 col6" >Black</th>        <th class="col_heading level0 col7" >White</th>        <th class="col_heading level0 col8" >Hispanic/Latino All Races</th>        <th class="col_heading level0 col9" >Uninsured</th>        <th class="col_heading level0 col10" >Currently Smoking</th>        <th class="col_heading level0 col11" >Adult Diabetics</th>        <th class="col_heading level0 col12" >Obesity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4567074_62ba_11eb_8466_3e22fb8af6eelevel0_row0" class="row_heading level0 row0" >175</th>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col0" class="data row0 col0" >AK-00</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col1" class="data row0 col1" >Don Young</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col2" class="data row0 col2" >Republican</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col3" class="data row0 col3" >$74,346</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col4" class="data row0 col4" >15.10%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col5" class="data row0 col5" >6.29%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col6" class="data row0 col6" >3.42%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col7" class="data row0 col7" >64.35%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col8" class="data row0 col8" >7.20%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col9" class="data row0 col9" >11.70%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col10" class="data row0 col10" >17.60%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col11" class="data row0 col11" >7.40%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow0_col12" class="data row0 col12" >32.60%</td>
#             </tr>
#             <tr>
#                         <th id="T_e4567074_62ba_11eb_8466_3e22fb8af6eelevel0_row1" class="row_heading level0 row1" >19</th>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col0" class="data row1 col0" >AL-01</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col1" class="data row1 col1" >Jerry L. Carl</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col2" class="data row1 col2" >Republican</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col3" class="data row1 col3" >$46,445</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col4" class="data row1 col4" >0.98%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col5" class="data row1 col5" >1.49%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col6" class="data row1 col6" >27.52%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col7" class="data row1 col7" >67.09%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col8" class="data row1 col8" >3.37%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col9" class="data row1 col9" >16.30%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col10" class="data row1 col10" >20.00%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col11" class="data row1 col11" >12.50%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow1_col12" class="data row1 col12" >34.40%</td>
#             </tr>
#             <tr>
#                         <th id="T_e4567074_62ba_11eb_8466_3e22fb8af6eelevel0_row2" class="row_heading level0 row2" >325</th>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col0" class="data row2 col0" >AL-02</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col1" class="data row2 col1" >Barry Moore</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col2" class="data row2 col2" >Republican</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col3" class="data row2 col3" >$48,290</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col4" class="data row2 col4" >0.42%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col5" class="data row2 col5" >1.10%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col6" class="data row2 col6" >32.14%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col7" class="data row2 col7" >62.92%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col8" class="data row2 col8" >3.68%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col9" class="data row2 col9" >16.20%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col10" class="data row2 col10" >19.90%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col11" class="data row2 col11" >12.70%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow2_col12" class="data row2 col12" >35.60%</td>
#             </tr>
#             <tr>
#                         <th id="T_e4567074_62ba_11eb_8466_3e22fb8af6eelevel0_row3" class="row_heading level0 row3" >229</th>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col0" class="data row3 col0" >AL-03</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col1" class="data row3 col1" >Mike Rogers</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col2" class="data row3 col2" >Republican</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col3" class="data row3 col3" >$45,832</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col4" class="data row3 col4" >0.18%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col5" class="data row3 col5" >1.84%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col6" class="data row3 col6" >25.97%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col7" class="data row3 col7" >69.31%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col8" class="data row3 col8" >3.12%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col9" class="data row3 col9" >15.70%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col10" class="data row3 col10" >20.20%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col11" class="data row3 col11" >12.50%</td>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow3_col12" class="data row3 col12" >34.40%</td>
#             </tr>
#             <tr>
#                         <th id="T_e4567074_62ba_11eb_8466_3e22fb8af6eelevel0_row4" class="row_heading level0 row4" >48</th>
#                         <td id="T_e4567074_62ba_11eb_8466_3e22fb8af6eerow4_col0" class="data row4 c

# %%
table_data_df.set_index('District').sort_values(by=['District'])
# Out:
#               Representative Political Party  Median Income  \
# District
# AK-00              Don Young      Republican        74346.0
# AL-01          Jerry L. Carl      Republican        46445.0
# AL-02            Barry Moore      Republican        48290.0
# AL-03            Mike Rogers      Republican        45832.0
# AL-04     Robert B. Aderholt      Republican        45387.0
# ...                      ...             ...            ...
# WI-08         Mike Gallagher      Republican        61423.0
# WV-01      David B. McKinley      Republican        46867.0
# WV-02       Alexander Mooney      Republican        48525.0
# WV-03        Carol D. Miller      Republican        36863.0
# WY-00             Liz Cheney      Republican        61584.0
#
#           American Indian/Alaskan Native     Asian     Black     White  \
# District
# AK-00                           0.151024  0.062895  0.034168  0.643519
# AL-01                           0.009774  0.014856  0.275239  0.670933
# AL-02                           0.004185  0.010974  0.321442  0.629199
# AL-03                           0.001835  0.018420  0.259665  0.693084
# AL-04                           0.006398  0.004476  0.074561  0.861266
# ...                                  ...       ...       ...       ...
# WI-08                           0.025837  0.021440  0.016375  0.899565
# WV-01                           0.001374  0.009511  0.026959  0.939530
# WV-02                           0.002166  0.008615  0.046199  0.916080
# WV-03                           0.000771  0.004026  0.040836  0.935664
# WY-00                           0.028014  0.010051  0.006347  0.914695
#
#           Hispanic/Latino All Races  Uninsured  Currently Smoking  \
# District
# AK-00                      0.071964      0.117              0.176
# AL-01                      0.033747      0.163              0.200
# AL-02                      0.036797      0.162              0.199
# AL-03                      0.031199      0.157              0.202
# AL-04                      0.065177      0.150              0.202
# ...                             ...        ...                ...
# WI-08                      0.054284      0.082              0.156
# WV-01                      0.012642      0.101              0.228
# WV-02                      0.021675      0.096              0.222
# WV-03                      0.007606      0.106              0.253
# WY-00                      0.100210      0.147              0.172
#
#           Adult Diabetics  Obesity
# District
# AK-00               0.074    0.326
# AL-01               0.125    0.344
# AL-02               0.127    0.356
# AL-03               0.125    0.344
# AL-04               0.123    0.345
# ...                   ...      ...
# WI-08               0.079    0.321
# WV-01               0.125    0.363
# WV-02               0.131    0.377
# WV-03               0.141    0.385
# WY-00               0.082    0.289
#
# [432 rows x 12 columns]

# %%
#Exporting dataframe to SQLite
table_data_df.to_html('Templates/data.html', index=False, classes=['table', 'table-striped', 'table-hover'])

# %%
table_data_df.to_html
# Out:
# <bound method DataFrame.to_html of     District        Representative Political Party Median Income  \
# 0      CA-20         Jimmy Panetta        Democrat         75460
# 1      FL-13         Charlie Crist        Democrat         52081
# 2      MN-01          Jim Hagedorn      Republican         61247
# 3      NJ-10  Donald M. Payne, Jr.        Democrat         59101
# 4      OH-05       Robert E. Latta      Republican         60500
# ..       ...                   ...             ...           ...
# 441    NY-18  Sean Patrick Maloney        Democrat         82731
# 442    OH-11       Marcia L. Fudge        Democrat         38747
# 443    PA-04        Madeleine Dean        Democrat         87168
# 444    TX-25        Roger Williams      Republican         71031
# 445    VA-09    H. Morgan Griffith      Republican         41520
#
#      American Indian/Alaskan Native     Asian     Black     White  \
# 0                          0.010521  0.054372  0.020214  0.579996
# 1                          0.002817  0.036200  0.124510  0.788818
# 2                          0.002967  0.027769  0.032288  0.893902
# 3                          0.002186  0.071249  0.514338  0.288077
# 4                          0.001743  0.013514  0.026318  0.912368
# ..                              ...       ...       ...       ...
# 441                        0.002368  0.029524  0.099362  0.761893
# 442                        0.002642  0.025795  0.524545  0.397482
# 443                        0.000419  0.065983  0.096447  0.795039
# 444                        0.004196  0.036372  0.088046  0.809937
# 445                        0.002304  0.016527  0.052325  0.909069
#
#      Hispanic/Latino All Races  Uninsured  Currently Smoking  Adult Diabetics  \
# 0                     0.541216      0.158              0.123            0.091
# 1                     0.106667      0.187              0.175            0.108
# 2                     0.067884      0.098              0.146            0.081
# 3                     0.211066      0.157              0.165            0.124
# 4                     0.052604      0.085              0.182            0.105
# ..                         ...        ...                ...              ...
# 441                   0.178123      0.099              0.150            0.085
# 442                   0.043880      0.136              0.242            0.155
# 443                   0.049858      0.066              0.139            0.085
# 444                   0.190213      0.173              0.142            0.091
# 445                   0.020296      0.118              0.188            0.107
#
#      Obesity
# 0      0.240
# 1      0.277
# 2      0.310
# 3      0.328
# 4      0.345
# ..       ...
# 441    0.267
# 442    0.379
# 443    0.253
# 444    0.302
# 445    0.312
#
# [446 rows x 13 columns]>
